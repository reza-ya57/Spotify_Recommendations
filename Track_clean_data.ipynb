# %%
import pandas as pd
import re

# %%
file_path = "./archive/tracks.csv"
track_df = pd.read_csv(file_path)
track_df.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
for column in track_df.columns:
    print(f'{column} has {track_df[column].isnull().sum()}')
# Out:
# id has 0
# name has 71
# popularity has 0
# duration_ms has 0
# explicit has 0
# artists has 0
# id_artists has 0
# release_date has 0
# danceability has 0
# energy has 0
# key has 0
# loudness has 0
# mode has 0
# speechiness has 0
# acousticness has 0
# instrumentalness has 0
# liveness has 0
# valence has 0
# tempo has 0
# time_signature has 0

# %%
release_date = track_df['release_date'].dropna()

# %%
release_date
# Out:
# 0         1922-02-22
# 1         1922-06-01
# 2         1922-03-21
# 3         1922-03-21
# 4               1922
#              ...
# 586667    2020-09-26
# 586668    2020-10-21
# 586669    2020-09-02
# 586670    2021-03-05
# 586671    2015-07-01
# Name: release_date, Length: 586672, dtype: object

# %%
release_date[realease_date.map(lambda x: type(x) != str)]
# Out:
# Series([], Name: release_date, dtype: object)

# %%
track_df['release_date'] = release_date.str.extract(r'(\d{4})')[0]

# %%
track_df.tail(10)
# Out:
#                             id                       name  popularity  \
# 586662  4Zp3rm12p5PiHToYJflmyy                 Meet Again          57
# 586663  4ow9HehIdFii1cggylW2k0                 四季予你 - DJ版          47
# 586664  1Kzjk1EyngBcP4T8x3fyqv   同行 (新加坡電視劇《愛...沒有距離》主題曲)          43
# 586665  0SjsIzJkZfDU7wlcdklEFR          John Brown's Song          66
# 586666  1ZwZsVZUiyFwIHMNpI3ERt                 Skyscraper           4
# 586667  5rgu12WBIHQtvej2MdHSH0                        云与海          50
# 586668  0NuWgxEp51CutD2pJoF4OM                      blind          72
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2  What They'll Say About Us          70
# 586670  45XJsGpFTyzbzeWK8VzR8S            A Day At A Time          58
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn           Mar de Emociones          38
#
#         duration_ms  explicit                          artists  \
# 586662       273587         0                   ['KIMSEJEONG']
# 586663       156393         0                     ['程響', '阿卓']
# ...

# %%
track_df.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
track_df.isnull().sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
track_df.dropna(inplace=True)

# %%
track_df
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
track_df['release_date'].value_counts()
# Out:
# 2020    13937
# 1999    12484
# 1998    12483
# 1997    12349
# 1996    12058
#         ...
# 1925      903
# 1923      657
# 1924      633
# 1922      276
# 1900        1
# Name: release_date, Length: 101, dtype: int64

# %%
track_df['popularity'].value_counts()
# Out:
# 0      44631
# 35     12231
# 23     12139
# 1      12024
# 36     11879
#        ...
# 96         2
# 98         1
# 99         1
# 95         1
# 100        1
# Name: popularity, Length: 101, dtype: int64

# %%
for column in artists_df.columns:
    print(f'{column} has {artists_df[column].isnull().sum()}')
# Out:
# id has 0
# followers has 13
# genres has 0
# name has 0
# popularity has 0

# %%
# bin release date by decade
decade = []
for year in track_df['release_date']:
    if (year >= 1940) & (year< 1950):
        decade = "1940's"
    elif (year >= 1950) & (year < 1960):
        decade = "1950's"
    elif (year >= 1960) & (year < 1970):
        decade = "1960's"
    elif (year >= 1970) & (year < 1980):
        decade = "1970's"
    elif (year >= 1980) & (year < 1990):
        decade = "1980's"
    elif (year >= 1990) & (year < 2000):
        decade = "1990's"
    elif (year >= 2000) & (year < 2010):
        decade = "2000's"
    elif (year >= 2010) & (year < 2020):
        decade = "2010's"
    else: 
        decade = "2020's"
    #end if
#end for

# %%
track_df['release_date'] = track_df['release_date'].astype(int)

# %%
track_df['release_decade'] =
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...
